# %% [markdown]
# # Predicting Evergreeness of Content with Decision Trees and Random Forests

# %%
## DATA DICTIONARY

# %%
import graphviz

# %%
import pandas as pd
import json

data = pd.read_csv("../../assets/dataset/stumbleupon.tsv", sep='\t')
data['title'] = data.boilerplate.map(lambda x: json.loads(x).get('title', ''))
data['body'] = data.boilerplate.map(lambda x: json.loads(x).get('body', ''))
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4  \
# 0           0.047059           0.023529
# 1           0.213904           0.144385
# 2           0.120155           0.042636
# 3           0.016667           0.000000
# 4           0.123457           0.043210
#
#                          ...                          linkwordscore  \
# 0                        ...                                     24
# 1                        ...                                     40
# 2                        ...                                     55
# 3                        ...                                     24
# 4                        ...                                     14
#
#    news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 0                0                            5424            170
# 1                0                            4973            187
# 2                0                            2240            258
# 3                0                            2737            120
# 4                0                           12032            162
#
#    numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 0                8               0.152941               0.079130     0
# 1                9               0.181818               0.125448     1
# 2               11               0.166667               0.057613     1
# 3                5               0.041667               0.100858     1
# 4               10               0.098765               0.082569     0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body
# 0  A sign stands outside the International Busine...
# 1  And that can be carried on a plane without the...
# 2  Apples The most popular source of antioxidants...
# 3  There was a period in my life when I had a lot...
# 4  Jersey sales is a curious business Whether you...
#
# [5 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7395 entries, 0 to 7394
# Data columns (total 29 columns):
# url                               7395 non-null object
# urlid                             7395 non-null int64
# boilerplate                       7395 non-null object
# alchemy_category                  7395 non-null object
# alchemy_category_score            7395 non-null object
# avglinksize                       7395 non-null float64
# commonlinkratio_1                 7395 non-null float64
# commonlinkratio_2                 7395 non-null float64
# commonlinkratio_3                 7395 non-null float64
# commonlinkratio_4                 7395 non-null float64
# compression_ratio                 7395 non-null float64
# embed_ratio                       7395 non-null float64
# framebased                        7395 non-null int64
# frameTagRatio                     7395 non-null float64
# hasDomainLink                     7395 non-null int64
# html_ratio                        7395 non-null float64
# image_ratio                       7395 non-null float64
# is_news                           7395 non-null object
# lengthyLinkDomain                 7395 non-null int64
# linkwordscore                     7395 non-null int64
# news_front_page                   7395 non-null object
# non_markup_alphanum_characters    7395 non-null int64
# numberOfLinks                     7395 non-null int64
# numwords_in_url                   7395 non-null int64
# parametrizedLinkRatio             7395 non-null float64
# spelling_errors_ratio             7395 non-null float64
# label                             7395 non-null int64
# title                             7383 non-null object
# body                              7338 non-null object
# dtypes: float64(12), int64(9), object(8)
# memory usage: 1.6+ MB

# %%
data.drop(labels = ['title', 'body'], axis = 1, inplace = True)

# %%
data = data[data['alchemy_category'] != '?']

# %%
data['alchemy_category'].unique()
# Out:
# array(['business', 'recreation', 'health', 'sports', '?',
#        'arts_entertainment', 'science_technology', 'gaming',
#        'culture_politics', 'computer_internet', 'law_crime', 'religion',
#        'weather', 'unknown'], dtype=object)

# %%
data[data['alchemy_category'] == '?']
# Out:
#                                                     url  urlid  \
# 5     http://www.conveniencemedical.com/genital-herp...   7018
# 7     http://www.insidershealth.com/article/racing_f...   3402
# 8     http://www.valetmag.com/the-handbook/features/...    477
# 9     http://www.howsweeteats.com/2010/03/24/cookies...   6731
# 13    http://www.thedailygreen.com/print-this/health...   1063
# 23    http://www.monicel.info/2008/08/03/original-te...   8945
# 24    http://blogs.babble.com/family-kitchen/2011/04...   2839
# 28    http://humor.cool-been.com/wp/supermodels-show...   2949
# 29    http://sportsillustrated.cnn.com/2011_swimsuit...   4156
# 32    http://www.chicandcharming.com/2008/01/ten-way...   8004
# 35                            http://nerdsmagazine.com/   3201
# 36    http://bitten.blogs.nytimes.com/2008/05/06/mic...   6704
# 38    http://www.peta.org/living/vegetarian-living/c...   3561
# 42    http://www.refinery29.com/holiday-nail-art-diy...   8138
# 44    http://sportsillustrated.cnn.com/2011_swimsuit...   1754
# 46                                 http://twenty1f.com/   4881
# 47    http://allrecipes.com/Recipe/Apple-Dumplings-I...   5483
# 49    http://hypersapien.hubpages.com/_hubfc/hub/Pro...   4781
# 55    http://www.phoenixnewtimes.com/2008-03-20/news...   7053
# 64    http://www.complex.com/city-guide/2011/07/best...   1033
# 65    http://www.abusynest.com/2010/10/nutella-cooki...   7822
# 66                            http://www.newsnow.co.uk/  10119
# 69    http://www.pauladeen.com/recipes/recipe_view/c...   9297
# 71    http://www.collegefashion.net/beauty-and-hair/...   6928
# 78        http://www.thisiswhyyourefat.com/?p=424409252   8073
# 80                         http://www.solarcooking.org/  10159
# 81    http://www.mybakingaddiction.com/cream-cheese-...   6514
# 88                     http://www.indianvanitycase.com/   1641
# 90    http://lifestyle.ca.msn.com/health-fitness/fit...   8438
# 96    http://www.crunchgear.com/2010/01/22/boogie-bo...   3738
# ...                                                 ...    ...
# 7297  http://momspark.net/pantry-recipe-chocolate-or...   3185
# 7298  http://www.medindia.net/news/healthwatch/Tooth...   2042
# 7302  http://momspark.net/st-patricks-day-sweet-reci...   3865
# 7306                        http://www.answergator.com/   3491
# 7314  http://www.bakespace.com/recipes/detail/Strawb...    364
# 7316  http://quadcities.myhomecareblog.com/2012/05/t...   6775
# 7323          http://www.truthaboutabs.com/ab?hop=m231g   4318
# 7325                 http://arch1design.com/blog?p=9514   7235
# 7326  http://community.livejournal.com/forestlace/13...   6406
# 7333         http://www.powerkitesdirect.com/kiteboard/   4706
# 7335  http://sportsillustrated.cnn.com/vault/swimsui...   8522
# 7337  http://www.insidershealth.com/article/helen_ph...  10101
# 7343        http://www.collegehumor.com/picture:1724723   5671
# 7344  http://www.heathersdish.com/1/healthy-spinach-...   9817
# 7345  http://arch1design.com/blog/2011/08/line-defen...    494
# 7350  http://www.polyvore.com/cool_school_uniforms/c...   2494
# 7356  http://embed.shortform.com/oceanguy/techproduc...   1374
# 7357        http://www.collegehumor.com/article:1770169   9081
# 7361  http://www.ivillage.com/holiday-main-dish-reci...   7211
# 7363  http://angieriver.com/recipes/better-than-sex-...   6186
# 7365                  http://cheezburger.com/6631333376  10446
# 7366      http://www.newsweek.com/id/43884/output/print   8329
# 7367  http://ca.askmen.com/sports/foodcourt_250/253_...   6416
# 7368  http://www.cafejohnsonia.com/2011/08/sourdough...   8442
# 7369   http://noblepig.com/2009/05/10/just-amazing.aspx   7202
# 7380  http://m.ivillage.com/wicked-good-chocolate-pe...   1823
# 7384  http://iammommy.typepad.com/i_am_baker/2011/02...   1061
# 7385  http://shopmarkethq.com/collections/brands-min...   5419
# 7389  http://www.worth1000.com/emailthis.asp?entry=5...   8923
# 7394  http://sportsillustrated.cnn.com/2011_swimsuit...     90
#
#                                             boilerplate alchemy_category  \
# 5     {"url":"conveniencemedical genital herpes home...                ?
# 7     {"url":"insidershealth article racing for reco...                ?
# 8     {"title":"Valet The Handbook 31 Days 31 days",...                ?
# 9     {"url":"howsweeteats 2010 03 24 cookies and cr...                ?
# 13    {"title":" ","body":" ","url":"thedailygreen p...                ?
# 23    {"title":"Original techniques to tie your shoe...                ?
# 24    {"title":" ","body":" ","url":"blogs babble fa...                ?
# 28    {"title":"Supermodels show off their bikini bo...                ?
# 29    {"title":"Genevieve Morton Swimsuit by Tyler R...                ?
# 32    {"title":"Ten ways to be Fabulous ","body":"On...                ?
# 35    {"url":"nerdsmagazine","title":"NerdsMagazine ...                ?
# 36    {"title":"Microwave Popcorn Minus the Ripoff m...                ?
# 38    {"title":"Creamy Raspberry Orange Popsicles PE...                ?
# 42    {"title":"Photo 1 Festive Funky Holiday Nail A...                ?
# 44    {"title":"Alyssa Miller Swimsuit by Charlie by...                ?
# 46    {"title":"Twenty1F twenty1f","body":"Jul23 Fra...                ?
# 47    {"title":"Apple Dumplings II Recipe Allrecipes...                ?
# 49    {"url":"hypersapien hubpages hubfc hub Pro Ath...                ?
# 55    {"title":" ","body":" ","url":"phoenixnewtimes...                ?
# 64    {"title":"The 25 Best Hot Dog Shops in the U S...                ?
# 65    {"title":"A Busy Nest Four Ingredient Nutella ...                ?
# 66    {"title":"NewsNow co uk The UK s 1 news portal...                ?
# 69    {"title":"Chocolate Gooey Butter Cookies Paula...                ?
# 71    {"title":"I Tried It Magnetic Nail Polish Coll...                ?
# 78    {"title":"Inside Out Spaghetti Meatballs This ...                ?
# 80    {"title":"Solar Cookers International ","body"...                ?
# 81    {"title":"Cream Cheese Pound Cake My Baking Ad...                ?
# 88    {"title":"Indian Vanity Case ","body":"With Va...                ?
# 90    {"title":" ","body":" ","url":"lifestyle ca ms...                ?
# 96    {"title":"Boogie Board writing tablet costs 30...                ?
# ...                                                 ...              ...
# 7297  {"title":"Pantry Recipe Chocolate Orange Zucch...                ?
# 7298  {"title":"Tooth Regeneration A Reality of Stem...                ?
# 7302  {"title":"St Patrick s Day Sweet Recipes Mom S...                ?
# 7306  {"title":"Get Straight Answers to Your Questio...                ?
# 7314  {"title":"Strawberry Cake Filling Recipe Detai...                ?
# 7316  {"title":"Technology and the Elderly Bettendor...                ?
# 7323  {"url":"truthaboutabs ab hop m231g","title":"H...                ?
# 7325  {"title":"Fluoride in our Water The Truth ","b...                ?
# 7326  {"title":"wild woman fashion joanna newsom ","...                ?
# 7333  {"url":"powerkitesdirect kiteboard","title":"B...                ?
# 7335  {"title":"Elsa Benitez SI Swimsuit Collection ...                ?
# 7337  {"url":"insidershealth article helen phillips ...                ?
# 7343  {"title":"How does it feel to know you re resp...                ?
# 7344  {"title":"Healthy Spinach Artichoke Dip Heathe...                ?
# 7345  {"title":"A New Line of Defense Against Sexual...                ?
# 7350  {"title":" ","body":" ","url":"polyvore cool s...                ?
# 7356  {"title":"Newegg TV How To Build a Computer Pa...                ?
# 7357  {"title":"Honest Textbook Titles by Kevin Holt...                ?
# 7361  {"title":" ","body":" ","url":"ivillage holida...                ?
# 7363  {"title":"Better than Sex Cake The Angieriver ...                ?
# 7365  {"url":"cheezburger 6631333376","title":"Choco...                ?
# 7366  {"title":"Money Happiness Newsweek money & hap...                ?
# 7367  {"title":" ","body":" ","url":"ca askmen sport...                ?
# 7368  {"title":"Sourdough Sour Cherry Bread Pudding ...                ?
# 7369  {"title":"Noble Pig Mini Peanut Butter Finger ...                ?
# 7380  {"url":"m ivillage wicked good chocolate peanu...                ?
# 7384  {"title":"Homemade Cake Mix i am baker ","body...                ?
# 7385  {"url":"shopmarkethq collections brands minkpi...                ?
# 7389  {"title":"Gummy Snake Worth1000 Contests ","bo...                ?
# 7394  {"title":"Esti Ginzburg Swimsuit by Letarte by...                ?
#
#      alchemy_category_score  avglinksize  commonlinkratio_1  \
# 5                         ?   119.000000           0.745455
# 7                         ?     1.883333           0.719697
# 8                         ?     0.471503           0.190722
# 9                         ?     2.410112           0.469325
# 13                        ?     0.000000           0.000000
# 23                        ?     4.327655           0.978758
# 24                        ?     1.786408           0.552632
# 28                        ?     3.417910           0.541176
# 29                        ?     1.154762           0.504425
# 32                        ?     1.292683           0.421965
# 35                        ?     1.888889           0.593750
# 36                        ?     2.618902           0.707317
# 38                        ?     2.881944           0.548223
# 42                        ?     1.769697           0.381818
# 44                        ?     1.158209           0.505917
# 46                        ?     2.133333           0.655738
# 47                        ?     2.328502           0.427778
# 49                        ?     2.854839           0.428571
# 55                        ?     2.278481           0.552419
# 64                        ?     1.127517           0.636364
# 65                        ?     2.334975           0.638132
# 66                        ?     3.731183           0.510638
# 69                        ?     2.336207           0.526316
# 71                        ?     3.265306           0.636364
# 78                        ?     2.230769           0.658537
# 80                        ?     2.531915           0.612245
# 81                        ?     1.268041           0.336134
# 88                        ?     1.404332           0.437722
# 90                        ?     2.557471           0.608247
# 96                        ?     3.596774           0.384615
# ...                     ...          ...                ...
# 7297                      ?     1.747126           0.347826
# 7298                      ?     2.228070           0.615584
# 7302                      ?     2.628571           0.616667
# 7306                      ?     2.500000           0.034483
# 7314                      ?     1.706522           0.317757
# 7316                      ?     2.240000           0.407407
# 7323                      ?     0.400000           0.000000
# 7325                      ?     4.089385           0.634021
# 7326                      ?     0.821918           0.373626
# 7333                      ?     1.266667           0.419355
# 7335                      ?     1.300000           0.297297
# 7337                      ?     1.883333           0.719697
# 7343                      ?     2.087500           0.410405
# 7344                      ?     1.362500           0.476190
# 7345                      ?     4.945701           0.786885
# 7350                      ?     3.244898           0.250000
# 7356                      ?     2.166667           0.275862
# 7357                      ?     1.638889           0.416667
# 7361                      ?     2.435013           0.770235
# 7363                      ?     2.272727           0.694444
# 7365                      ?     2.477612           0.478022
# 7366                      ?     3.031250           0.473684
# 7367                      ?     2.079208           0.445455
# 7368                      ?     1.553968           0.526235
# 7369                      ?     4.329730           0.760218
# 7380                      ?     1.600000           0.622222
# 7384                      ?     2.411765           0.513986
# 7385                      ?     1.939394           0.459732
# 7389                      ?     1.000000           0.358974
# 7394                      ?     1.158209           0.505917
#
#       commonlinkratio_2  commonlinkratio_3  commonlinkratio_4  \
# 5              0.581818           0.290909           0.018182
# 7              0.265152           0.113636           0.015152
# 8              0.036082           0.000000           0.000000
# 9              0.101227           0.018405           0.003067
# 13             0.000000           0.000000           0.000000
# 23             0.895792           0.669138           0.422044
# 24             0.149123           0.052632           0.017544
# 28             0.270588           0.176471           0.117647
# 29             0.427729           0.023599           0.000000
# 32             0.306358           0.011561           0.000000
# 35             0.171875           0.062500           0.046875
# 36             0.336043           0.119241           0.051491
# 38             0.238579           0.106599           0.040609
# 42             0.181818           0.048485           0.006061
# 44             0.428994           0.023669           0.000000
# 46             0.213115           0.196721           0.196721
# 47             0.205556           0.061111           0.019444
# 49             0.103896           0.038961           0.000000
# 55             0.266129           0.052419           0.020161
# 64             0.048485           0.000000           0.000000
# 65             0.389105           0.198444           0.085603
# 66             0.244681           0.042553           0.021277
# 69             0.210526           0.090226           0.037594
# 71             0.404040           0.262626           0.121212
# 78             0.317073           0.243902           0.170732
# 80             0.285714           0.183673           0.061224
# 81             0.063025           0.016807           0.012605
# 88             0.188612           0.032028           0.021352
# 90             0.268041           0.077320           0.030928
# 96             0.107692           0.092308           0.061538
# ...                 ...                ...                ...
# 7297           0.130435           0.032609           0.010870
# 7298           0.296104           0.122078           0.044156
# 7302           0.350000           0.116667           0.041667
# 7306           0.000000           0.000000           0.000000
# 7314           0.084112           0.018692           0.000000
# 7316           0.203704           0.074074           0.055556
# 7323           0.000000           0.000000           0.000000
# 7325           0.422680           0.206186           0.134021
# 7326           0.021978           0.000000           0.000000
# 7333           0.193548           0.032258           0.032258
# 7335           0.081081           0.027027           0.000000
# 7337           0.265152           0.113636           0.015152
# 7343           0.109827           0.017341           0.000000
# 7344           0.185185           0.021164           0.010582
# 7345           0.553279           0.327869           0.151639
# 7350           0.118056           0.041667           0.000000
# 7356           0.000000           0.000000           0.000000
# 7357           0.147436           0.012821           0.000000
# 7361           0.409922           0.107050           0.052219
# 7363           0.333333           0.194444           0.055556
# 7365           0.137363           0.010989           0.000000
# 7366           0.092105           0.026316           0.026316
# 7367           0.109091           0.027273           0.000000
# 7368           0.217593           0.075617           0.026235
# 7369           0.414169           0.359673           0.237057
# 7380           0.266667           0.000000           0.000000
# 7384           0.325175           0.241259           0.206294
# 7385           0.255034           0.140940           0.080537
# 7389           0.068376           0.025641           0.017094
# 7394           0.428994           0.023669           0.000000
#
#                             ...                          linkwordscore  \
# 5                           ...                                     12
# 7                           ...                                      5
# 8                           ...                                     17
# 9                           ...                                     14
# 13                          ...                                      0
# 23                          ...                                     85
# 24                          ...                                     20
# 28                          ...                                     68
# 29                          ...                                     80
# 32                          ...                                     28
# 35                          ...                                     18
# 36                          ...                                     28
# 38                          ...                                     52
# 42                          ...                                     54
# 44                          ...                                     79
# 46                          ...                                     16
# 47                          ...                                     33
# 49                          ...                                     16
# 55                          ...                                     13
# 64                          ...                                     15
# 65                          ...                                     35
# 66                          ...                                     72
# 69                          ...                                     18
# 71                          ...                                     14
# 78                          ...                                     28
# 80                          ...                                     14
# 81                          ...                                     11
# 88                          ...                                     29
# 90                          ...                                     16
# 96                          ...                                      7
# ...                         ...                                    ...
# 7297                        ...                                     18
# 7298                        ...                                     39
# 7302                        ...                                     43
# 7306                        ...                                     16
# 7314                        ...                                     18
# 7316                        ...                                     15
# 7323                        ...                                      4
# 7325                        ...                                     27
# 7326                        ...                                     15
# 7333                        ...                                     14
# 7335                        ...                                     17
# 7337                        ...                                      5
# 7343                        ...                                     53
# 7344                        ...                                     18
# 7345                        ...                                     45
# 7350                        ...                                     19
# 7356                        ...                                     17
# 7357                        ...                                     45
# 7361                        ...                                     75
# 7363                        ...                                     17
# 7365                        ...                                     46
# 7366                        ...                                     12
# 7367                        ...                                     31
# 7368                        ...                                     50
# 7369                        ...                                     20
# 7380                        ...                                     40
# 7384                        ...                                     26
# 7385                        ...                                     72
# 7389                        ...                                     36
# 7394                        ...                                     78
#
#       news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 5                   ?                            4368             55
# 7                   ?                           27656            132
# 8                   0                            2471            194
# 9                   ?                           11459            326
# 13                  0                            4091              5
# 23                  0                           20757           4990
# 24                  0                            3760            114
# 28                  0                             536             85
# 29                  ?                             490            339
# 32                  0                            2531            173
# 35                  1                            2419             64
# 36                  ?                           10422            369
# 38                  0                            1987            197
# 42                  0                            1200            165
# 44                  ?                             494            338
# 46                  1                            3457             61
# 47                  0                            4791            360
# 49                  ?                            4191             77
# 55                  0                           17131            248
# 64                  0                            4372            165
# 65                  0                            3824            257
# 66                  ?                             915             94
# 69                  0                            5472            133
# 71                  0                            8663             99
# 78                  ?                            1000             41
# 80                  ?                            3871             49
# 81                  0                            9499            238
# 88                  1                            4742            281
# 90                  0                           11480            194
# 96                  ?                           13636             65
# ...               ...                             ...            ...
# 7297                0                            2953             92
# 7298                0                            6396            385
# 7302                0                            1652            120
# 7306                0                             700             58
# 7314                0                            3667            107
# 7316                0                            2944             54
# 7323                ?                             731             15
# 7325                ?                           10462            194
# 7326                ?                            1484             91
# 7333                ?                            1294             31
# 7335                0                             912             37
# 7337                ?                           27752            132
# 7343                0                            1614            173
# 7344                0                            4610            189
# 7345                ?                            6714            244
# 7350                0                            3697            144
# 7356                ?                             929             29
# 7357                ?                            1503            156
# 7361                ?                            1533            383
# 7363                0                            1726             36
# 7365                0                            1845            182
# 7366                ?                            6775             76
# 7367                ?                            2380            110
# 7368                0                            4401            648
# 7369                ?                           14073            367
# 7380                ?                             496             45
# 7384                ?                            6208            286
# 7385                ?                            1447            298
# 7389                ?                             886            117
# 7394                ?                             515            338
#
#       numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 5                   3               0.054545               0.087356     0
# 7                   4               0.068182               0.148551     0
# 8                   7               0.644330               0.125000     1
# 9                   4               0.236196               0.094412     1
# 13                 11               0.000000               0.083333     1
# 23                  6               0.992786               0.157954     1
# 24                  5               0.043860               0.000000     1
# 28                  6               0.035294               0.159574     1
# 29                  4               0.005900               0.033113     1
# 32                  3               0.202312               0.095116     0
# 35                  0               0.000000               0.089249     0
# 36                  6               0.067751               0.083538     1
# 38                  7               0.076142               0.000000     1
# 42                  5               0.139394               0.061224     0
# 44                  4               0.005917               0.025000     1
# 46                  0               0.049180               0.094340     0
# 47                  5               0.466667               0.131579     1
# 49                  6               0.324675               0.136719     0
# 55                 13               0.366935               0.235294     0
# 64                  8               0.096970               0.078431     1
# 65                  3               0.268482               0.107914     1
# 66                  0               0.531915               0.007092     0
# 69                  7               0.323308               0.048544     1
# 71                  7               0.050505               0.093098     0
# 78                  0               0.780488               0.090909     1
# 80                  0               0.040816               0.117647     1
# 81                  5               0.399160               0.067864     1
# 88                  0               0.241993               0.099071     0
# 90                  7               0.278351               0.090909     1
# 96                  8               0.092308               0.089005     0
# ...               ...                    ...                    ...   ...
# 7297                6               0.097826               0.074653     1
# 7298               11               0.197403               0.042945     1
# 7302                4               0.091667               0.104895     0
# 7306                0               0.103448               0.230769     0
# 7314                5               0.065421               0.092179     1
# 7316                4               0.074074               0.131148     0
# 7323                1               0.000000               0.134921     0
# 7325                1               0.092784               0.071988     0
# 7326                2               0.439560               0.129630     0
# 7333                2               0.096774               0.068182     1
# 7335                7               0.108108               0.043478     0
# 7337                6               0.068182               0.130112     0
# 7343                1               0.023121               0.019231     0
# 7344                4               0.206349               0.080745     1
# 7345                5               0.045082               0.098413     0
# 7350                4               0.479167               0.166667     0
# 7356                9               0.068966               0.044199     0
# 7357                1               0.019231               0.112676     0
# 7361                6               0.127937               0.083333     1
# 7363                5               0.000000               0.128000     1
# 7365                0               0.049451               0.032258     1
# 7366                2               0.052632               0.105556     0
# 7367                5               0.100000               0.125000     1
# 7368                5               0.077160               0.084195     1
# 7369                3               0.250681               0.083110     1
# 7380                7               0.044444               0.000000     0
# 7384                4               0.188811               0.108796     1
# 7385                6               0.104027               0.159091     0
# 7389                4               0.205128               0.058824     0
# 7394                4               0.005917               0.134146     0
#
#                                                   title  \
# 5                             Genital Herpes Treatment
# 7     Racing For Recovery by Dean Johnson racing for...
# 8                    Valet The Handbook 31 Days 31 days
# 9           Cookies and Cream Brownies How Sweet It Is
# 13
# 23          Original techniques to tie your shoe laces
# 24
# 28        Supermodels show off their bikini bods Humor
# 29    Genevieve Morton Swimsuit by Tyler Rose Swimwe...
# 32                             Ten ways to be Fabulous
# 35              NerdsMagazine Everything About Android
# 36    Microwave Popcorn Minus the Ripoff microwave p...
# 38    Creamy Raspberry Orange Popsicles PETA org cre...
# 42    Photo 1 Festive Funky Holiday Nail Art DIYs fe...
# 44    Alyssa Miller Swimsuit by Charlie by Matthew Z...
# 46                                    Twenty1F twenty1f
# 47    Apple Dumplings II Recipe Allrecipes com apple...
# 49    Pro Athletes Who Went Broke pro athletes who w...
# 55
# 64    The 25 Best Hot Dog Shops in the U S the 25 be...
# 65         A Busy Nest Four Ingredient Nutella Cookies
# 66                NewsNow co uk The UK s 1 news portal
# 69        Chocolate Gooey Butter Cookies Pauladeen com
# 71     I Tried It Magnetic Nail Polish College Fashion
# 78    Inside Out Spaghetti Meatballs This Is Why You...
# 80                         Solar Cookers International
# 81         Cream Cheese Pound Cake My Baking Addiction
# 88                                  Indian Vanity Case
# 90
# 96    Boogie Board writing tablet costs 30 features ...
# ...                                                 ...
# 7297  Pantry Recipe Chocolate Orange Zucchini Bread ...
# 7298  Tooth Regeneration A Reality of Stem Cell and ...
# 7302          St Patrick s Day Sweet Recipes Mom Spark
# 7306            Get Straight Answers to Your Questions
# 7314             Strawberry Cake Filling Recipe Detail
# 7316  Technology and the Elderly Bettendorf Moline S...
# 7323  How to Lose Stubborn Belly Fat Get Flat Sexy S...
# 7325                   Fluoride in our Water The Truth
# 7326                  wild woman fashion joanna newsom
# 7333  Best Beginner Kiteboard lightwind beginner kit...
# 7335  Elsa Benitez SI Swimsuit Collection 2002 Sport...
# 7337  Helen Phillips The Biggest Loser by Dean Johns...
# 7343  How does it feel to know you re responsible fo...
# 7344      Healthy Spinach Artichoke Dip Heather s Dish
# 7345      A New Line of Defense Against Sexual Assault
# 7350
# 7356  Newegg TV How To Build a Computer Part 3 Insta...
# 7357  Honest Textbook Titles by Kevin Holt on Colleg...
# 7361
# 7363          Better than Sex Cake The Angieriver Show
# 7365  Chocolate Chip S mores Cookies of the Day choc...
# 7366  Money Happiness Newsweek money & happiness - n...
# 7367
# 7368  Sourdough Sour Cherry Bread Pudding with Cherr...
# 7369  Noble Pig Mini Peanut Butter Finger Cheesecake...
# 7380        iVillage s 25 Most Popular Recipes of 2010
# 7384                      Homemade Cake Mix i am baker
# 7385                         MARKET HQ Brands MINKPINK
# 7389                    Gummy Snake Worth1000 Contests
# 7394  Esti Ginzburg Swimsuit by Letarte by Lisa Cabr...
#
#                                                    body
# 5     Genital herpes is caused by herpes simplex vir...
# 7     Racing For Recovery is the growing idea that d...
# 8     Resolutions are for suckers Instead of swearin...
# 9     More brownies It seems that I can t get throug...
# 13
# 23    http www damascus online com guide p 4 8734 ie...
# 24
# 28    May 1222 Miranda Kerr Irina Shayk Behati Prins...
# 29    Genevieve Morton 24 hails from Benoni South Af...
# 32    One of my favorite bloggers Ashe Mischief over...
# 35    If you are from your Windows default look woul...
# 36    May 6 2008 2 49 pm By MARK BITTMAN Somehow I v...
# 38     creamy raspberry-orange popsicles are a refre...
# 42    Festive Funky Holiday Nail Art DIYs Snowfall G...
# 44    Alyssa Miller 20 was born in Los Angeles Calif...
# 46    Jul23 Francesca Lanzavecchia born in Pavia Ita...
# 47     whole apples are wrapped in homemade pastry, ...
# 49    rate or flagPin It By HypersapienWhat Happened...
# 55
# 64    Wikipedia tells us that a hot dog is a sausage...
# 65    A Busy Nest Four Ingredient Nutella Cookies Fo...
# 66     newsnow.co.uk > the uk's #1 news portal newsn...
# 69    Recipe Courtesy of Paula DeenIf the word butte...
# 71    Written by Elizabeth University of Missouri Th...
# 78
# 80    Solar Cookers International A 501 c 3 nonprofi...
# 81    by Jamie on June 10 2011 Poundcake For some re...
# 88    With Valentine s Day drawing nearer thoughts o...
# 90
# 96    Going completely paperless just got a bit easi...
# ...                                                 ...
# 7297  I have a deep love for zucchini breads of all ...
# 7298  Currently a donor organ becomes a necessity as...
# 7302  About Mom SparkAmy is a SAHM of two boys and a...
# 7306   questions, answers, question, answer, facts, ...
# 7314  Feb 05 2012 You are here Home Recipes Strawber...
# 7316  Where s the Q My dad frequently shouts random ...
# 7323  5 Foods that FIGHT Abdominal Fat by Mike Geary...
# 7325  Fluoride is the name given to a group of compo...
# 7326  I wish she would smile more Who knows if it is...
# 7333  Lightwind Beginner Kiteboard 479 The Flying Ph...
# 7335   elsa benitez, si swimsuit, si swimsuit models...
# 7337  Who is Helen Phillips The story behind her inc...
# 7343   a funny picture from collegehumor stick figur...
# 7344  by Heather on June 30 2011 There s one appetiz...
# 7345  Smart women know it s wise to beware when out ...
# 7350
# 7356  Newegg TV How To Build a Computer Part 3 Insta...
# 7357  var sid 72Y5T7 var c var b BF BB SCRIPT docume...
# 7361
# 7363  Kristina had the night off earlier in the week...
# 7365   click to see everything you need to know abou...
# 7366  All in all it was probably a mistake to look f...
# 7367
# 7368  It s summer and I don t usually make bread pud...
# 7369  Well I survived yesterday It turns out my thro...
# 7380
# 7384  I gotta be honest with you Most of the time I ...
# 7385  MARKET HQ Brands MINKPINK What s New Shop By B...
# 7389  Entry Details Entered 12 1 2008 12 08 35 PM Ra...
# 7394  Esti Ginzburg 20 is a native of Tel Aviv Israe...
#
# [2342 rows x 29 columns]

# %% [markdown]
# ## Predicting "Greenness" Of Content

# %% [markdown]
# This dataset comes from [stumbleupon](https://www.stumbleupon.com/), a web page recommender. A description of the columns is below:

# %% [markdown]
# FieldName|Type|Description
# ---------|----|-----------
# url|string|Url of the webpage to be classified
# title|string|Title of the article
# body|string|Body text of article
# urlid|integer| StumbleUpon's unique identifier for each url
# boilerplate|json|Boilerplate text
# alchemy_category|string|Alchemy category (per the publicly available Alchemy API found at www.alchemyapi.com)
# alchemy_category_score|double|Alchemy category score (per the publicly available Alchemy API found at www.alchemyapi.com)
# avglinksize| double|Average number of words in each link
# commonlinkratio_1|double|# of links sharing at least 1 word with 1 other links / # of links
# commonlinkratio_2|double|# of links sharing at least 1 word with 2 other links / # of links
# commonlinkratio_3|double|# of links sharing at least 1 word with 3 other links / # of links
# commonlinkratio_4|double|# of links sharing at least 1 word with 4 other links / # of links
# compression_ratio|double|Compression achieved on this page via gzip (measure of redundancy)
# embed_ratio|double|Count of number of <embed> usage
# frameBased|integer (0 or 1)|A page is frame-based (1) if it has no body markup but have a frameset markup
# frameTagRatio|double|Ratio of iframe markups over total number of markups
# hasDomainLink|integer (0 or 1)|True (1) if it contains an <a> with an url with domain
# html_ratio|double|Ratio of tags vs text in the page
# image_ratio|double|Ratio of <img> tags vs text in the page
# is_news|integer (0 or 1) | True (1) if StumbleUpon's news classifier determines that this webpage is news
# lengthyLinkDomain| integer (0 or 1)|True (1) if at least 3 <a> 's text contains more than 30 alphanumeric characters
# linkwordscore|double|Percentage of words on the page that are in hyperlink's text
# news_front_page| integer (0 or 1)|True (1) if StumbleUpon's news classifier determines that this webpage is front-page news
# non_markup_alphanum_characters|integer| Page's text's number of alphanumeric characters
# numberOfLinks|integer Number of <a>|markups
# numwords_in_url| double|Number of words in url
# parametrizedLinkRatio|double|A link is parametrized if it's url contains parameters or has an attached onClick event
# spelling_errors_ratio|double|Ratio of words not found in wiki (considered to be a spelling mistake)
# label|integer (0 or 1)|User-determined label. Either evergreen (1) or non-evergreen (0); available for train.tsv only

# %% [markdown]
# ### What are 'evergreen' sites?
#
# > #### Evergreen sites are those that are always relevant.  As opposed to breaking news or current events, evergreen websites are relevant no matter the time or season.
#
# > #### A sample of URLs is below, where label = 1 are 'evergreen' websites

# %%
data[['url', 'label']].head()

# %% [markdown]
# ### Exercises to Get Started

# %% [markdown]
# > ### Exercise: 1. In a group: Brainstorm 3 - 5 features you could develop that would be useful for predicting evergreen websites.
#  ###  Exercise: 2. After looking at the dataset, can you model or quantify any of the characteristics you wanted?
# - I.E. If you believe high-image content websites are likely to be evergreen, how can you build a feature that represents that?
# - I.E. If you believe weather content is likely NOT to be evergreen, how might you build a feature that represents that?
#
# ### Split up and develop 1-3 of the those features independently.

# %% [markdown]
# > ### Exercise: 3. Does being a news site affect evergreeness?
# Compute or plot the percentage of news related evergreen sites.

# %%
data['is_news'].replace('?', 0, inplace = True)

# %% [markdown]
# > ### Exercise: 4. Does category in general affect evergreeness?
# Plot the rate of evergreen sites for all Alchemy categories.

# %%
# ... #

# %% [markdown]
# > ### Exercise: 5. How many articles are there per category?

# %%
# ... #

# %% [markdown]
# > #### Let's try extracting some of the text content.
# > ### Exercise: 6. Create a feature for the title containing 'recipe'.
# Is the % of evegreen websites higher or lower on pages that have recipe in the the title?

# %%
data['recipe'] = data['title'].str.contains('recipe')

# %%
y = data['is_news']

# %% [markdown]
# ###  Let's Explore Some Decision Trees

# %% [markdown]
#  ### Demo: Build a decision tree model to predict the "evergreeness" of a given website.

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

X = data[['image_ratio', 'html_ratio', 'recipe', 'label']].dropna()
y = X['label']
X.drop('label', axis=1, inplace=True)
    
    
# Fits the model
model.fit(X, y)

# Helper function to visualize Decision Trees (creates a file tree.png)

from sklearn.tree import export_graphviz
from os import system 
def build_tree_image(model):
    dotfile = open("tree.dot", 'w')
    export_graphviz(model,
                              out_file = dotfile,
                              feature_names = X.columns)
    dotfile.close()
    system("dot -Tpng tree.dot -o tree.png")
    
build_tree_image(model)

# %% [markdown]
# ## Decision Trees in scikit-learn

# %% [markdown]
#  ### Exercise: Evaluate the decision tree using cross-validation; use AUC as the evaluation metric.

# %%
import sklearn
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.80)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-3f1164001796> in <module>()
#       1 import sklearn
# ----> 2 X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.80)
#
# /home/ga/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.pyc in train_test_split(*arrays, **options)
#    1687         test_size = 0.25
#    1688
# -> 1689     arrays = indexable(*arrays)
#    1690
#    1691     if stratify is not None:
#
# /home/ga/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in indexable(*iterables)
#     204         else:
#     205             result.append(np.array(X))
# --> 206     check_consistent_length(*result)
#     207     return result
#     208
#
# /home/ga/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [7383, 7395]

# %% [markdown]
# ###  Adjusting Decision Trees to Avoid Overfitting

# %% [markdown]
#  ### Demo: Control for overfitting in the decision model by adjusting the maximum number of questions (max_depth) or the minimum number of records in each final node (min_samples_leaf)

# %%
model = DecisionTreeClassifier(
                max_depth = 2,
                min_samples_leaf = 5)

model.fit(X, y)
build_tree_image(model)

# %% [markdown]
#  ### Demo: Build a random forest model to predict the evergreeness of a website.

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 20)
    
model.fit(X, y)
var_df = pd.DataFrame(data=[X.columns, model.feature_importances_])

# %%
a = var_df.T
a.sor
# Out:
#              0          1
# 0  image_ratio   0.446265
# 1   html_ratio    0.52449
# 2       recipe  0.0292458

# %% [markdown]
# ### Demo: Extracting importance of features

# %%
features = X.columns
feature_importances = model.feature_importances_

features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort('Importance Score', inplace=True, ascending=False)

features_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-931dcc02b1f7> in <module>()
#       3
#       4 features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
# ----> 5 features_df.sort('Importance Score', inplace=True, ascending=False)
#       6
#       7 features_df.head()
#
# /home/ga/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
#  ### Exercise: Evaluate the Random Forest model using cross-validation; increase the number of estimators and view how that improves predictive performance.

# %%
# ... #

# %% [markdown]
# ##  Independent Practice: Evaluate Random Forest Using Cross-Validation

# %% [markdown]
# 1. Continue adding input variables to the model that you think may be relevant
# 2. For each feature:
#   - Evaluate the model for improved predictive performance using cross-validation
#   - Evaluate the _importance_ of the feature
#   -
# 3. **Bonus**: Just like the 'recipe' feature, add in similar text features and evaluate their performance.

# %%
# ... #
