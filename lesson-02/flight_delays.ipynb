# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ga-students/dat6melb/master/lessons/lesson-10_old/assets/dataset/flight_delays.csv?token=AMqwHQ5seMsp7HFP0PYecd2XXcWfTydXks5avIcQwA%3D%3D')

# %%
df.head(10)
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  AIRLINE_ID CARRIER  \
# 0             1            4  2015-01-01             AA       19805      AA
# 1             1            4  2015-01-01             AA       19805      AA
# 2             1            4  2015-01-01             AA       19805      AA
# 3             1            4  2015-01-01             AA       19805      AA
# 4             1            4  2015-01-01             AA       19805      AA
# 5             1            4  2015-01-01             AA       19805      AA
# 6             1            4  2015-01-01             AA       19805      AA
# 7             1            4  2015-01-01             AA       19805      AA
# 8             1            4  2015-01-01             AA       19805      AA
# 9             1            4  2015-01-01             AA       19805      AA
#
#    ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# ...

# %%
#Altered data originating from the Kaggle 2015 Flight Delays competition
df['UNIQUE_CARRIER'].unique()
# Out:
# array(['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 'HA', 'MQ', 'NK', 'OO', 'UA',
#        'US', 'VX', 'WN'], dtype=object)

# %%
df['FL_DATE'].head()
# Out:
# 0    2015-01-01
# 1    2015-01-01
# 2    2015-01-01
# 3    2015-01-01
# 4    2015-01-01
# Name: FL_DATE, dtype: object
