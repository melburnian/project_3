# %%
import pandas as pd
from pandas.io import sql
from IPython.core.display import Image, display

# %%
import sqlite3

# %%
conn = sqlite3.connect('dat-test.db')

# %%
#if db is not in use anymore
#conn.close()

# %%
data=pd.read_csv('../dataset/rossmann-stores.csv', low_memory=False)
data.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
data.to_sql('stores', con=conn, if_exists='replace', index=False)

# %%
query = 'select * from stores limit 10'

sql.read_sql(query, con=conn)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
# 5      6         a          a                310.0                       12.0
# 6      7         a          c              24000.0                        4.0
# 7      8         a          a               7520.0                       10.0
# 8      9         a          c               2030.0                        8.0
# 9     10         a          a               3160.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
#Task: Write a query that selects column store and Assortment when Assortment is a or b

# %%
sql.read_sql(query, con=conn)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
# 5      6         a          a                310.0                       12.0
# 6      7         a          c              24000.0                        4.0
# 7      8         a          a               7520.0                       10.0
# 8      9         a          c               2030.0                        8.0
# 9     10         a          a               3160.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
query='select count(Promo2SinceWeek) as promo, count(*) as total,  count(*) - count(Promo2SinceWeek) as diff, 100.0 * count(Promo2SinceWeek) / count(1) as percentage from stores'
sql.read_sql(query, con=conn)

# %% [markdown]
# # Walmart sales

# %% [markdown]
# ## Load tables to sql

# %%
# Out:
#    promo  total  diff  percentage
# 0    571   1115   544   51.210762

# %%
sales=pd.read_csv('../dataset/walmart-sales.csv', low_memory=False)
sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales IsHoliday
# 0      1     1  2010-02-05      24924.50     False
# 1      1     1  2010-02-12      46039.49      True
# 2      1     1  2010-02-19      41595.55     False
# 3      1     1  2010-02-26      19403.54     False
# 4      1     1  2010-03-05      21827.90     False

# %%
features=pd.read_csv('../dataset/features.csv', low_memory=False)
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106     False
# 1        NaN        NaN        NaN  211.242170         8.106      True
# 2        NaN        NaN        NaN  211.289143         8.106     False
# 3        NaN        NaN        NaN  211.319643         8.106     False
# 4        NaN        NaN        NaN  211.350143         8.106     False

# %%
sql.read_sql('select * from stores limit 10', con=conn)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
# 5      6         a          a                310.0                       12.0
# 6      7         a          c              24000.0                        4.0
# 7      8         a          a               7520.0                       10.0
# 8      9         a          c               2030.0                        8.0
# 9     10         a          a               3160.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %% [markdown]
# ## Join
# Sqlite has only 2 joins available - left join and join

# %%
sql.read_sql('select count(*) from stores st left join features f on st.Store = f.Store', con=conn)
# Out:
#    count(*)
# 0      9260

# %%
sql.read_sql('select * from sales limit 10', con=conn)
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50          0
# 1      1     1  2010-02-12      46039.49          1
# 2      1     1  2010-02-19      41595.55          0
# 3      1     1  2010-02-26      19403.54          0
# 4      1     1  2010-03-05      21827.90          0
# 5      1     1  2010-03-12      21043.39          0
# 6      1     1  2010-03-19      22136.64          0
# 7      1     1  2010-03-26      26229.21          0
# 8      1     1  2010-04-02      57258.43          0
# 9      1     1  2010-04-09      42960.91          0

# %% [markdown]
# #### Aggregate functions

# %%
#Aggregate functions
query = 'select Date, sum(weekly_sales) as sum_sales from sales group by date order by sum_sales desc'
sql.read_sql(query, con=conn)
# Out:
#            Date    sum_sales
# 0    2010-12-24  80931415.60
# 1    2011-12-23  76998241.31
# 2    2011-11-25  66593605.26
# 3    2010-11-26  65821003.24
# 4    2010-12-17  61820799.85
# 5    2011-12-16  60085695.94
# 6    2010-12-10  55666770.39
# 7    2011-12-09  55561147.70
# 8    2012-04-06  53502315.87
# 9    2012-07-06  51253021.88
# 10   2010-04-02  50423831.26
# 11   2012-02-17  50197056.96
# 12   2010-06-04  50188543.12
# 13   2012-02-10  50009407.92
# 14   2010-12-03  49909027.88
# 15   2010-02-05  49750740.50
# 16   2012-06-08  49651171.78
# 17   2011-12-02  49390556.49
# 18   2010-07-02  48917484.50
# 19   2011-06-03  48771994.18
# 20   2011-02-18  48716164.12
# 21   2011-04-22  48676692.06
# 22   2011-11-04  48655544.30
# 23   2010-05-07  48503243.52
# 24   2011-11-11  48474224.75
# 25   2012-06-15  48412110.70
# 26   2010-02-12  48336677.63
# 27   2012-09-07  48330059.31
# 28   2012-06-01  48281649.72
# 29   2010-02-19  48276993.78
# ..          ...          ...
# ...

# %%
conn_chinook = sqlite3.connect('chinook.db')

# %%
Image(filename='../img/db.png')
#http://www.sqlitetutorial.net/sqlite-sample-database/

# %%
#like
sql.read_sql('select * from artists where Name like "%DC"', con=conn_chinook)
# Out:
#    ArtistId   Name
# 0         1  AC/DC

# %%
# how many days do you work in this company.
query = 'SELECT EmployeeId, HireDate, (2018-05-01 - HireDate) as WorkDays FROM employees'
sql.read_sql(query, con=conn_chinook)
# Out:
#    EmployeeId             HireDate  WorkDays
# 0           1  2002-08-14 00:00:00        10
# 1           2  2002-05-01 00:00:00        10
# 2           3  2002-04-01 00:00:00        10
# 3           4  2003-05-03 00:00:00         9
# 4           5  2003-10-17 00:00:00         9
# 5           6  2003-10-17 00:00:00         9
# 6           7  2004-01-02 00:00:00         8
# 7           8  2004-03-04 00:00:00         8

# %%
#second highest UnitPrice
sql.read_sql('SELECT max(UnitPrice) FROM invoice_items WHERE UnitPrice < (SELECT max(UnitPrice) FROM invoice_items)', con=conn_chinook)
# Out:
#    max(UnitPrice)
# 0            0.99

# %% [markdown]
# # QUERIES
# ## Chinook database
# ### 1. How many employees and customers are in database?
# ### 2. What are 10 the most frequent customers countries?
# ### 3. Who is the youngest employee
# ### 4. How many playlists names starts with letter A? How many finishes with "NG"?
# ### 5. Display 5  composers that appear the most frequently
# ### 6. What is the third highest UnitPrice?

# %% [markdown]
# ## Sales data
#
# 1. Which "holiday" week has the highest sales value and which the lowest? (Same for no-holiday week).
# 2. What is the percentage of Null values in features table for Store with ID 2?
# 3. How many different dates do we have in sales table?
# 4. What is the maximum and minimum value for Competition distance column
# 5. How many (and which) weeks exceed 60000000 dollars in sales? Which of them are holidays?
# 6. What is the country and name of top 5 customers?
